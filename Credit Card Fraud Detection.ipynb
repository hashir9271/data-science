# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# <span style="font-size:20px"> 0---->> Normal Transaction</span>
#
# <span style="font-size:20px"> 1---->> fraud Transaction</span>

# %% [markdown]
# # Splitting the Normal Transaction and Fraud Transaction

# %%
legit = df[df['Class'] == 0]
fraud = df[df['Class'] == 1]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# <span style="font-size:20px">Since our data set is very unbalanced so we are taking sample of Normal Transaction to make our data set balanced</span>

# %%
legit_sample = legit.sample(n=492)
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 22729    32404.0 -2.170640 -2.151372  1.513747 -1.022984  1.784026 -2.682317
# 250115  154735.0  2.064121 -0.080258 -1.079899  0.416406 -0.174049 -1.215090
# 72308    54651.0 -0.005855 -2.292529  0.497292  0.656670 -1.348502  1.100225
# 190330  128789.0  0.034379  0.748816  0.099673 -0.805547  0.630032 -0.546821
# 144919   86492.0 -0.168489 -0.090777  1.111993 -2.560771  0.020174 -0.306429
# ...          ...       ...       ...       ...       ...       ...       ...
# 190745  128969.0 -6.416152 -2.843983 -3.051791  2.213895  0.173614  1.731560
# 11513    19903.0  1.303928 -0.689781  0.677966 -0.347662 -1.095737 -0.151280
# 81082    58777.0  1.364356 -0.595155  0.371359 -0.615819 -1.170101 -1.093548
# 208838  137295.0  1.354381 -1.512845 -0.822892  0.180104 -0.913437 -0.084932
# 110237   71736.0 -1.853324 -1.122892  2.981019  2.010422 -1.771001  2.970187
#
# ...

# %% [markdown]
# <span style="font-size:20px">Concatenating Sample data set and fraud data set as it is now balanced data set </span>

# %%
concat_df = pd.concat([legit_sample , fraud],axis = 0)
concat_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 22729    32404.0 -2.170640 -2.151372  1.513747 -1.022984  1.784026 -2.682317
# 250115  154735.0  2.064121 -0.080258 -1.079899  0.416406 -0.174049 -1.215090
# 72308    54651.0 -0.005855 -2.292529  0.497292  0.656670 -1.348502  1.100225
# 190330  128789.0  0.034379  0.748816  0.099673 -0.805547  0.630032 -0.546821
# 144919   86492.0 -0.168489 -0.090777  1.111993 -2.560771  0.020174 -0.306429
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
 concat_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
concat_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      93540.815041 -0.079032 -0.062831  0.116838 -0.005892  0.028033
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.026360 -0.076423  0.039554 -0.031042  ...  0.045142  0.030662
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.014446  0.018392  0.001516 -0.002366 -0.045245  0.012191  0.002851
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       89.261199
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = concat_df.drop(columns='Class' , axis =1)
Y = concat_df['Class']

# %% [markdown]
# <span style="font-size:20px">X-----> Contains all the data columns except Class column</span>
#
# <span style="font-size:20px">Y-----> Contains Labels 0 and 1</span>

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 22729    32404.0 -2.170640 -2.151372  1.513747 -1.022984  1.784026 -2.682317
# 250115  154735.0  2.064121 -0.080258 -1.079899  0.416406 -0.174049 -1.215090
# 72308    54651.0 -0.005855 -2.292529  0.497292  0.656670 -1.348502  1.100225
# 190330  128789.0  0.034379  0.748816  0.099673 -0.805547  0.630032 -0.546821
# 144919   86492.0 -0.168489 -0.090777  1.111993 -2.560771  0.020174 -0.306429
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 22729     0
# 250115    0
# 72308     0
# 190330    0
# 144919    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# <span style="font-size:20px">Training the model</span>

# %%
X_train ,X_test, Y_train, Y_test = train_test_split(X,Y,test_size =0.2,stratify=Y,random_state=2)

# %%
model = LogisticRegression()

# %%
model.fit(X_train , Y_train)
# Out:
# C:\Users\ok\.conda\New folder\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# <span style="font-size:20px">Checking the accuracy of training data</span>

# %%
X_train_prediction = model.predict(X_train)
Accuracy_Train = accuracy_score(X_train_prediction,Y_train)
Accuracy_Train
# Out:
# 0.951715374841169

# %% [markdown]
# <span style="font-size:20px">Checking the accuracy of test data</span>

# %%
X_test_prediction = model.predict(X_test)
Accuracy_Test = accuracy_score(X_test_prediction , Y_test)
Accuracy_Test
# Out:
# 0.949238578680203

# %% [markdown]
# # TEST INTERFACE

# %%
print("\n--- Credit Card Fraud Detection Test Interface ---")
print("Enter transaction details below. Type 'quit' at any prompt to exit.")

# Get the feature names in the order the model expects them
feature_names = X.columns.tolist()

while True:
    input_data_list = []
    try:
        print("\nPlease enter the following transaction features:")
        for feature in feature_names:
            user_input = input(f"  Enter value for {feature}: ")
            if user_input.lower() == 'quit':
                raise KeyboardInterrupt # Use an exception to break out cleanly

            # Attempt to convert input to float
            input_data_list.append(float(user_input))

        # Convert list to NumPy array and reshape for prediction (1 row, 30 columns)
        input_data_array = np.array(input_data_list).reshape(1, -1)

        # Make prediction
        prediction = model.predict(input_data_array)
        prediction_proba = model.predict_proba(input_data_array) # Get probabilities

        # Display result
        print("\n--- Prediction Result ---")
        if prediction[0] == 0:
            print("  Prediction: Legitimate Transaction")
        else:
            print("  Prediction: >> Fraudulent Transaction <<")

        print(f"  Probability -> [Legitimate: {prediction_proba[0][0]:.4f}, Fraudulent: {prediction_proba[0][1]:.4f}]")
        print("-------------------------\n")

    except ValueError:
        # Handle cases where input is not a valid number
        print("\nError: Invalid input. Please enter numeric values only.")
        print("Restarting transaction input...\n")
        continue # Skip rest of the loop and start asking for input again

    except KeyboardInterrupt:
        # Handle user typing 'quit'
        print("\nExiting test interface.")
        break # Exit the while loop

    except Exception as e:
        # Catch any other unexpected errors
        print(f"\nAn unexpected error occurred: {e}")
        print("Exiting test interface.")
        break

print("--- Interface Closed ---")

# %% [markdown]
# # Final Objectives

# %% [markdown]
# 1) Data Exploration
#
# >Loaded and explored creditcard.csv.
#
# >Checked for null values and class distribution.
#
# >Identified severe class imbalance (fraud cases = very few).
#
# 2) Data Preprocessing
#
# >Separated the dataset into legit and fraud transactions.
#
# >Took a sample of legitimate transactions to balance the dataset.
#
# >Merged the sampled data to create a balanced training dataset.
#
# 3) Feature Selection
#
# >Selected all columns except Class as features (X).
#
# >Set the target label (Y) as the Class column.
#
# 4) Model Training
#
# >Split data into training and testing sets (80/20 split, stratified).
#
# >Trained a Logistic Regression model.
#
# 5) Model Evaluation
#
# >Calculated training accuracy which is 95 %
#
# >Calculated testing accuracy which is 94 %
#
# >Used accuracy_score to evaluate predictions.
