# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set(style="whitegrid")

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape

# %%
df.duplicated().sum()
# Out:
# 0

# %%
specific_str = ['.','/','?','*','-','_']
df.isin(specific_str).sum()

# %%
df

# %%
df[['First Name','Last Name']] =df['Name'].str.split(" ",n=1,expand = True) 
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = df.drop( columns = 'Name')
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  First Name  \
# 0           A/5 21171   7.2500   NaN        S     Braund,
# 1            PC 17599  71.2833   C85        C    Cumings,
# ...

# %%
col = df.pop("First Name")
df.insert(3,"First Name",col)
df
# Out:
#      PassengerId  Survived  Pclass  First Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3     Braund,    male  22.0      1      0
# 1              2         1       1    Cumings,  female  38.0      1      0
# 2              3         1       3  Heikkinen,  female  26.0      0      0
# 3              4         1       1   Futrelle,  female  35.0      1      0
# 4              5         0       3      Allen,    male  35.0      0      0
# ..           ...       ...     ...         ...     ...   ...    ...    ...
# 886          887         0       2   Montvila,    male  27.0      0      0
# 887          888         1       1     Graham,  female  19.0      0      0
# 888          889         0       3   Johnston,  female   NaN      1      2
# 889          890         1       1       Behr,    male  26.0      0      0
# 890          891         0       3     Dooley,    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  \
# ...

# %%
col = df.pop("Last Name")
df.insert(4,"Last Name",col)
df
# Out:
#      PassengerId  Survived  Pclass  First Name  \
# 0              1         0       3     Braund,
# 1              2         1       1    Cumings,
# 2              3         1       3  Heikkinen,
# 3              4         1       1   Futrelle,
# 4              5         0       3      Allen,
# ..           ...       ...     ...         ...
# 886          887         0       2   Montvila,
# 887          888         1       1     Graham,
# 888          889         0       3   Johnston,
# 889          890         1       1       Behr,
# 890          891         0       3     Dooley,
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df['First Name'] = df['First Name'].str.rstrip(',')
df
# Out:
#      PassengerId  Survived  Pclass First Name  \
# 0              1         0       3     Braund
# 1              2         1       1    Cumings
# 2              3         1       3  Heikkinen
# 3              4         1       1   Futrelle
# 4              5         0       3      Allen
# ..           ...       ...     ...        ...
# 886          887         0       2   Montvila
# 887          888         1       1     Graham
# 888          889         0       3   Johnston
# 889          890         1       1       Behr
# 890          891         0       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df.rename(columns ={"PassengerId" : "PassengerID"},inplace = True)
df
# Out:
#      PassengerID  Survived  Pclass First Name  \
# 0              1         0       3     Braund
# 1              2         1       1    Cumings
# 2              3         1       3  Heikkinen
# 3              4         1       1   Futrelle
# 4              5         0       3      Allen
# ..           ...       ...     ...        ...
# 886          887         0       2   Montvila
# 887          888         1       1     Graham
# 888          889         0       3   Johnston
# 889          890         1       1       Behr
# 890          891         0       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df['Survived'] = df['Survived'].astype(int)
df
# Out:
#      PassengerID  Survived  Pclass First Name  \
# 0              1         0       3     Braund
# 1              2         1       1    Cumings
# 2              3         1       3  Heikkinen
# 3              4         1       1   Futrelle
# 4              5         0       3      Allen
# ..           ...       ...     ...        ...
# 886          887         0       2   Montvila
# 887          888         1       1     Graham
# 888          889         0       3   Johnston
# 889          890         1       1       Behr
# 890          891         0       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df['Survived'] = df['Survived'].map({0:'No', 1:'Yes'})
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df.info()

# %%
df = df.drop(columns = 'Cabin')
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df = df.replace('NaN','')
df

# %%
df['Embarked'] = df['Embarked'].fillna('')
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
for x in df.index:
    if df.loc[x,'Embarked'] == '':
        df.drop(x,inplace=True)
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].median(),inplace = True)
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerID  889 non-null    int64
#  1   Survived     889 non-null    object
#  2   Pclass       889 non-null    int64
#  3   First Name   889 non-null    object
#  4   Last Name    889 non-null    object
#  5   Sex          889 non-null    object
#  6   Age          889 non-null    float64
#  7   SibSp        889 non-null    int64
#  8   Parch        889 non-null    int64
#  9   Ticket       889 non-null    object
#  10  Fare         889 non-null    float64
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 122.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x=df["Fare"])
plt.show()

# %%
sns.boxplot(x=df["Age"])
plt.show()

# %%
l_percentile = df['Fare'].quantile(0.01)
u_percentile = df['Fare'].quantile(0.99)
df['Fare'] = df['Fare'].clip(l_percentile,u_percentile )
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
sns.boxplot(x=df["Fare"])
plt.show()

# %%
l_percentile = df['Fare'].quantile(0.01)
u_percentile = df['Fare'].quantile(0.99)
df['Fare'] = df['Fare'].clip(l_percentile,u_percentile )
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %%
sns.boxplot(x=df["Fare"])
plt.show()

# %%
sns.countplot(x="Sex", data=df)
plt.title("Passenger Count by Gender")
plt.show()

# %%
sns.violinplot(x="Sex", y="Age", data=df)
plt.title("Violin Plot of Age by Gender")
plt.show()

# %%
sns.barplot(x="Pclass", y="Fare", data=df)
plt.title("Average Fare by Class")
plt.show()

# %%
sns.boxplot(x="Pclass", y="Age", data=df)
plt.title("Age Distribution by Class")
plt.show()

# %%
sns.boxplot(data=df,x='Survived',y='Age',hue='Sex')
plt.show()

# %%
sns.histplot(df["Age"], kde=True, bins=30)
plt.title("Age Distribution with KDE")
plt.show()

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#              PassengerID    Pclass       Age     SibSp     Parch      Fare
# PassengerID     1.000000 -0.035330  0.031319 -0.057686 -0.001657  0.012703
# Pclass         -0.035330  1.000000 -0.336512  0.081656  0.016824 -0.548193
# Age             0.031319 -0.336512  1.000000 -0.232543 -0.171485  0.093707
# SibSp          -0.057686  0.081656 -0.232543  1.000000  0.414542  0.160887
# Parch          -0.001657  0.016824 -0.171485  0.414542  1.000000  0.217532
# Fare            0.012703 -0.548193  0.093707  0.160887  0.217532  1.000000

# %%
sns.heatmap(corr,annot = True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df_numeric =df[['Age','Fare','Pclass','Survived']]
plt.figure(figsize=(20,10))
sns.pairplot(df_numeric,hue='Survived',palette="bright")
plt.show()
# Out:
# C:\Users\ok\.conda\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
specific=['Yes']
total_survived = df['Survived'].isin(specific).sum()
print("Total Number of Survived Passenger : ",total_survived)
# Out:
# Total Number of Survived Passenger :  340

# %%
 df[(df["Survived"] == 'Yes') & (df["Sex"] == "female")].count()
# Out:
# PassengerID    231
# Survived       231
# Pclass         231
# First Name     231
# Last Name      231
# Sex            231
# Age            231
# SibSp          231
# Parch          231
# Ticket         231
# Fare           231
# Embarked       231
# dtype: int64

# %%
 df[(df["Survived"] == 'Yes') & (df["Sex"] == "male")].count()
# Out:
# PassengerID    109
# Survived       109
# Pclass         109
# First Name     109
# Last Name      109
# Sex            109
# Age            109
# SibSp          109
# Parch          109
# Ticket         109
# Fare           109
# Embarked       109
# dtype: int64

# %%
df[(df['Survived'] == 'Yes' ) & ((df['Age'] >=25)&(df['Age'] <=30))].count()
# Out:
# PassengerID    100
# Survived       100
# Pclass         100
# First Name     100
# Last Name      100
# Sex            100
# Age            100
# SibSp          100
# Parch          100
# Ticket         100
# Fare           100
# Embarked       100
# dtype: int64

# %%
df[(df['Age'] >=25)&(df['Age'] <=30).count()].count()
# Out:
# PassengerID    611
# Survived       611
# Pclass         611
# First Name     611
# Last Name      611
# Sex            611
# Age            611
# SibSp          611
# Parch          611
# Ticket         611
# Fare           611
# Embarked       611
# dtype: int64

# %%
df[(df['Survived'] == 'Yes' ) & ((df['Age'] >=25)&(df['Age'] <=30))& (df['Sex'] == 'female')].count()
# Out:
# PassengerID    65
# Survived       65
# Pclass         65
# First Name     65
# Last Name      65
# Sex            65
# Age            65
# SibSp          65
# Parch          65
# Ticket         65
# Fare           65
# Embarked       65
# dtype: int64

# %%
df
# Out:
#      PassengerID Survived  Pclass First Name  \
# 0              1       No       3     Braund
# 1              2      Yes       1    Cumings
# 2              3      Yes       3  Heikkinen
# 3              4      Yes       1   Futrelle
# 4              5       No       3      Allen
# ..           ...      ...     ...        ...
# 886          887       No       2   Montvila
# 887          888      Yes       1     Graham
# 888          889       No       3   Johnston
# 889          890      Yes       1       Behr
# 890          891       No       3     Dooley
#
#                                       Last Name     Sex   Age  SibSp  Parch  \
# 0                               Mr. Owen Harris    male  22.0      1      0
# 1    Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                   Miss. Laina  female  26.0      0      0
# 3            Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# ...

# %% [markdown]
# # Final Observation

# %% [markdown]
# In this analysis, I explored the Titanic dataset to uncover key insights related to passenger survival.
# 1. Data Loading & Inspection
# > Imported the dataset and examined its structure.
# > The dataset consists of 891 rows and 12 columns.
# > Identified missing values in Age, Cabin, and Embarked columns.
#
# 2. Data Cleaning
# > Checked for missing values and handled them appropriately.
# > Removed duplicate entries and verified data consistency.
# > Identified special characters or anomalies in certain columns.
#
# 3. Exploratory Data Analysis (EDA)
# > Performed statistical analysis to understand key distributions.
# > Used Seaborn and Matplotlib to visualize survival trends.
# > Explored correlations between survival and features like gender, class, fare, and age.
#
# 4. Key Findings
# > Gender & Class Played a Crucial Role – Women and first-class passengers had higher survival rates.
# Fare & Age Trends – Higher fares were associated with better survival chances, and younger passengers had a greater likelihood of survival.
# > Embarkation Impact – Survival rates varied based on the port of embarkation.
